# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read

audio_filename = 'Subbu.wav'
sample_rate, speech_audio = read(audio_filename)

# Convert speech audio to a NumPy array 
speech_audio = np.asarray(speech_audio)

# Rest of the code (FFT, plotting, iFFT) 
X = np.fft.fft(x)

# Get the amplitude of the frequency spectrum
amplitude = np.abs(X) / len(X)  # Normalize by signal length

# Plot the amplitude spectrum
plt.plot(amplitude[:len(amplitude)//2])  # Plot only positive frequencies
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Amplitude Spectrum of the Speech Signal")
plt.show()

# Perform inverse FFT to recover the signal from the frequency domain
x_recovered = np.fft.ifft(X)

# Check if the recovered signal is close to the original signal
print("Difference between original and recovered signal:", np.linalg.norm(x - x_recovered))
# Out:
# Difference between original and recovered signal: 9.723088112029953e-15
